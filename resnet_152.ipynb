# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !unzip /content/gdrive/MyDrive/DogsDataSet.zip

# %%
import os, time
import numpy as np
import random
random.seed(42)
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score, classification_report

import torch
torch.manual_seed(42)
from torch import nn
from torch.optim import SGD, Adam
from torch.utils.data import DataLoader, RandomSampler
from torch.utils.data.dataset import Dataset
from torchvision.models import resnet
from torchvision import transforms, datasets, models
from torch.optim.lr_scheduler import ReduceLROnPlateau

print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.12.1+cu113 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15109MB, multi_processor_count=40)

# %%
def load_transform_images(images_path, presplit, train_split, test_split, val_split, batch_size, threads, mean, std):
    train_transform = transforms.Compose([
                                         #transforms.RandomRotation(degrees=15),
                                         #transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
                                         #transforms.RandomResizedCrop((224,224)),
                                         transforms.Resize((224,224)),
                                         transforms.RandomHorizontalFlip(),
                                         transforms.ToTensor(),
                                         transforms.Normalize(torch.Tensor(mean),
                                                              torch.Tensor(std))])

    test_transform = transforms.Compose([
                                        transforms.Resize((224,224)),
                                        #transforms.CenterCrop((224,224)),
                                        transforms.ToTensor(),
                                        transforms.Normalize(torch.Tensor(mean),
                                                             torch.Tensor(std))])

    val_transform = transforms.Compose([
                                       transforms.Resize((224,224)),
                                       #transforms.CenterCrop((224,224)),
                                       transforms.ToTensor(),
                                       transforms.Normalize(torch.Tensor(mean),
                                                            torch.Tensor(std))])

    if presplit:
        try:
            training_set = datasets.ImageFolder(root=images_path+'/train', transform=train_transform)
            validation_set = datasets.ImageFolder(root=images_path+'/val', transform=val_transform)
        except FileNotFoundError:
            raise Exception('Not presplit into Training and Validation sets')
        try:
            testing_set = datasets.ImageFolder(root=images_path+'/test', transform=test_transform)
        except:
            testing_set = validation_set
        dataset = training_set
    else:
        dataset = datasets.ImageFolder(root=images_path, transform=train_transform)
        train_size = int(train_split * len(dataset))
        test_size = int(test_split * len(dataset))
        val_size = len(dataset) - train_size - test_size
        training_set, testing_set, validation_set = torch.utils.data.random_split(dataset, [train_size, test_size, val_size])
    
    training_set_loader = DataLoader(training_set, batch_size=batch_size, num_workers=threads, shuffle=True)
    validation_set_loader = DataLoader(validation_set, batch_size=batch_size, num_workers=threads, shuffle=True)
    testing_set_loader = DataLoader(testing_set, batch_size=batch_size, num_workers=threads, shuffle=False)

    return training_set_loader, testing_set_loader, validation_set_loader, dataset, training_set, testing_set, validation_set

def load_network(net_model, net_name, dropout_ratio, class_names, unfrozen_layers):
    for name, child in net_model.named_children():
        if name in unfrozen_layers:
            print(name + ' is unfrozen')
            for param in child.parameters():
                param.requires_grad = True
        else:
            print(name + ' is frozen')
            for param in child.parameters():
                param.requires_grad = False

    if net_name.startswith('resnet'):
        num_ftrs = net_model.fc.in_features
        net_model.fc = nn.Sequential(nn.Linear(num_ftrs, 256),
                                     nn.ReLU(),
                                     nn.Dropout(p=dropout_ratio),
                                     nn.Linear(256, len(class_names)))

    elif net_name.startswith('vgg'):
        num_ftrs = net_model.classifier[6].in_features
        net_model.classifier[6] = nn.Sequential(nn.Linear(num_ftrs, 256),
                                                nn.ReLU(),
                                                nn.Dropout(p=dropout_ratio),
                                                nn.Linear(256, len(class_names)))
    display(net_model)
    
    total_params = sum(param.numel() for param in net_model.parameters())
    print(f'{total_params:,} total parameters')

    total_trainable_params = sum(param.numel() for param in net_model.parameters() if param.requires_grad)
    print(f'{total_trainable_params:,} training parameters')
    
    return net_model

# %%
def plot_images_per_class(images_path, mode, title):
    data_folder = images_path+'/'+mode+'/'
    item_dict = {root.split('/')[-1]: len(files) for root, _, files in os.walk(data_folder)}
   
    plt.figure(figsize=(20,8))
    plt.bar(list(item_dict.keys())[1:], list(item_dict.values())[1:], color='g')
    plt.title(title)
    plt.xticks(rotation=90)
    plt.xlabel('Class')
    plt.ylabel('Number of Images')
    plt.show()

def plot_grid_images(training_set, batch_size, class_names, mean, std, rows=3, columns=3, size=14):
    sampler = RandomSampler(training_set, num_samples=batch_size, replacement=True)
    train_loader = DataLoader(training_set, sampler=sampler, shuffle=False, batch_size=batch_size, num_workers=0)
    
    dataiter = iter(train_loader)
    images, labels = dataiter.next()

    plt.figure(figsize=(size,size))
    for i in range(rows*columns):
        plt.subplot(rows, columns, i+1)
        plt.title(class_names[labels.numpy()[i]])
        img = images[i].permute(1,2,0)
        img = torch.tensor(std)*img + torch.tensor(mean)
        plt.axis('off')
        plt.imshow(img, interpolation='none')
        plt.tight_layout()

# %%
def train_model(results_path, model_name, model, train_loader, val_loader, lr, epoch, momentum, weight_decay, patience, n_epochs_stop):
    """
    """
    #if not os.path.exists(results_path+'/'+model_name):
    #    os.makedirs(results_path+'/'+model_name)
        
    criterion = nn.CrossEntropyLoss()
    optimizer = Adam(model.parameters(), lr=lr)
    #optimizer = SGD(model.parameters(), lr=lr, momentum=momentum, weight_decay=weight_decay)
    scheduler = ReduceLROnPlateau(optimizer, patience=patience, factor=0.1, verbose=True)
    
    loaders = {'train': train_loader, 'val': val_loader}
    losses = {'train': [], 'val': []}
    accuracies = {'train': [], 'val': []}
    
    y_testing = []
    preds = []
    
    min_val_loss = np.Inf
    epochs_no_improv = 0
    
    if torch.cuda.is_available():
        if torch.cuda.device_count() > 1:
            model = nn.DataParallel(model)
        print(f'Using {torch.cuda.device_count()} GPUs')
        model.cuda()
    else:
        print('Using CPU')
    
    start = time.time()
    for epoch in range(epochs):
        for mode in ['train', 'val']:
            if mode == 'train':
                model.train()
            if mode == 'val':
                model.eval()
            
            epoch_loss = 0
            epoch_acc = 0
            samples = 0

            for i, (inputs, targets) in enumerate(loaders[mode]):
                if torch.cuda.is_available():
                    inputs = inputs.cuda()
                    targets = targets.cuda()
                
                optimizer.zero_grad()
                output = model(inputs)
                loss = criterion(output, targets)
                
                if mode == 'train':
                    loss.backward()
                    optimizer.step()
                else:
                    y_testing.extend(targets.data.tolist())
                    preds.extend(output.max(1)[1].tolist())
                
                if torch.cuda.is_available():
                    acc = accuracy_score(targets.data.cuda().cpu().numpy(), output.max(1)[1].cuda().cpu().numpy())
                else:
                    acc = accuracy_score(targets.data, output.max(1)[1])

                epoch_loss += loss.data.item()*inputs.shape[0]
                epoch_acc += acc*inputs.shape[0]
                samples += inputs.shape[0]
                
                if i % (len(loaders[mode])//5) == 0:
                    print(f'[{mode}] Epoch {epoch+1}/{epochs} Iteration {i+1}/{len(loaders[mode])} Loss: {epoch_loss/samples:0.2f} Accuracy: {epoch_acc/samples:0.2f}')
            
            epoch_loss /= samples
            epoch_acc /= samples
            losses[mode].append(epoch_loss)
            accuracies[mode].append(epoch_acc)
            
            print(f'[{mode}] Epoch {epoch+1}/{epochs} Iteration {i+1}/{len(loaders[mode])} Loss: {epoch_loss:0.2f} Accuracy: {epoch_acc:0.2f}')
            
            if mode == 'val':
                scheduler.step(epoch_loss)
        
        if mode == 'val':
            if epoch_loss < min_val_loss:
                # torch.save(model.state_dict(), '/kaggle/working/'+str(model_name)+'.pth')
                torch.save(model.state_dict(), '/content/'+str(model_name)+'.pth')
                epochs_no_improv = 0
                min_val_loss = epoch_loss
            else:
                epochs_no_improv += 1
                print(f'Epochs with no improvement {epochs_no_improv}')
                if epochs_no_improv == n_epochs_stop:
                    print('Early stopping!')
                    return model, (losses, accuracies), y_testing, preds
                # model.load_state_dict(torch.load('/kaggle/working/'+str(model_name)+'.pth'))
                model.load_state_dict(torch.load('/content/'+str(model_name)+'.pth'))
                
    print(f'Training time: {time.time()-start} min.')
    return model, (losses, accuracies), y_testing, preds

def test_model(model_name, model, test_loader):
    # model.load_state_dict(torch.load('/kaggle/working/'+str(model_name)+'.pth'))
    model.load_state_dict(torch.load('/content/'+str(model_name)+'.pth'))

    if torch.cuda.is_available():
        model.cuda()
    model.eval()
    
    preds = []
    trues = []
    
    for i, (inputs, targets) in enumerate(test_loader):
        if torch.cuda.is_available():
            inputs = inputs.cuda()
            pred = model(inputs).data.cuda().cpu().numpy().copy()
        else:
            pred = model(inputs).data.numpy().copy()
            
        true = targets.numpy().copy()
        preds.append(pred)
        trues.append(true)

        if i % (len(test_loader)//5) == 0:
            print(f'Iteration {i+1}/{len(test_loader)}')
    return np.concatenate(preds), np.concatenate(trues)

# %%
def display_confusion_matrix(results_path, model_name, y_true, preds, class_names, annot, figsize=(9,7), fontsize=14):
    #if not os.path.exists(results_path+'/'+model_name):
    #    os.makedirs(results_path+'/'+model_name)

    acc = accuracy_score(y_true, preds.argmax(1))
    score = f1_score(y_true, preds.argmax(1), average='micro')
    cm = confusion_matrix(y_true, preds.argmax(1))
    df_cm = pd.DataFrame(cm, index=class_names, columns=class_names)
    np.set_printoptions(precision=2)
    
    string1 = 'Confusion Matrix for Testing Data'
    string2 = f'Accuracy is {acc:0.3f}; F1-score is {score:0.3f}'
    title_str = string1.center(len(string2))+'\n'+string2

    plt.figure(figsize=figsize)
    sns.set(font_scale=1.2)
    sns.heatmap(df_cm, annot=annot, annot_kws={'size': fontsize}, fmt='d')
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.title(title_str)
    
    #plt.savefig(str(results_path)+'/'+str(model_name)+'/'+str(model_name)+'_conf_mat.png')
    
def plot_logs_classification(results_path, model_name, logs):
    """
    """
    #if not os.path.exists(results_path+'/'+model_name):
    #    os.makedirs(results_path+'/'+model_name)
        
    training_losses, training_accuracies, test_losses, test_accuracies = \
        logs[0]['train'], logs[1]['train'], logs[0]['val'], logs[1]['val']
    
    plt.figure(figsize=(18,6))
    plt.subplot(121)
    plt.plot(training_losses)
    plt.plot(test_losses)
    plt.legend(['Training Loss', 'Validation Loss'])
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.grid()
    
    plt.subplot(122)
    plt.plot(training_accuracies)
    plt.plot(test_accuracies)
    plt.legend(['Training Accuracy', 'Validation Accuracy'])
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.grid()

# %%
images_path = '/content/images/Images/'
results_path = images_path+'_results'
presplit = False
train_split = 0.5
val_split = 0.25
test_split = 0.25
batch_size = 128
threads = 0
mean = [0.485, 0.456, 0.406]
std = [0.229, 0.224, 0.225]

training_set_loader, testing_set_loader, validation_set_loader, dataset, training_set, testing_set, validation_set = \
                  load_transform_images(images_path, presplit, train_split, test_split, val_split, batch_size, threads, mean, std)

class_names = dataset.classes
class_names = [classes[10:] for classes in class_names]
print(class_names)
# Out:
# ['Chihuahua', 'Japanese_spaniel', 'Maltese_dog', 'Pekinese', 'Shih-Tzu', 'Blenheim_spaniel', 'papillon', 'toy_terrier', 'Rhodesian_ridgeback', 'Afghan_hound', 'basset', 'beagle', 'bloodhound', 'bluetick', 'black-and-tan_coonhound', 'Walker_hound', 'English_foxhound', 'redbone', 'borzoi', 'Irish_wolfhound', 'Italian_greyhound', 'whippet', 'Ibizan_hound', 'Norwegian_elkhound', 'otterhound', 'Saluki', 'Scottish_deerhound', 'Weimaraner', 'Staffordshire_bullterrier', 'American_Staffordshire_terrier', 'Bedlington_terrier', 'Border_terrier', 'Kerry_blue_terrier', 'Irish_terrier', 'Norfolk_terrier', 'Norwich_terrier', 'Yorkshire_terrier', 'wire-haired_fox_terrier', 'Lakeland_terrier', 'Sealyham_terrier', 'Airedale', 'cairn', 'Australian_terrier', 'Dandie_Dinmont', 'Boston_bull', 'miniature_schnauzer', 'giant_schnauzer', 'standard_schnauzer', 'Scotch_terrier', 'Tibetan_terrier', 'silky_terrier', 'soft-coated_wheaten_terrier', 'West_Highland_white_terrier', 'Lhasa', 'flat-coated_retriever', 'curly-coated_retriever', 'golden_retriever', 'Labrador_retriever', 'Chesapeake_Bay_retriever', 'German_short-haired_pointer', 'vizsla', 'English_setter', 'Irish_setter', 'Gordon_setter', 'Brittany_spaniel', 'clumber', 'English_springer', 'Welsh_springer_spaniel', 'cocker_spaniel', 'Sussex_spaniel', 'Irish_water_spaniel', 'kuvasz', 'schipperke', 'groenendael', 'malinois', 'briard', 'kelpie', 'komondor', 'Old_English_sheepdog', 'Shetland_sheepdog', 'collie', 'Border_collie', 'Bouvier_des_Flandres', 'Rottweiler', 'German_shepherd', 'Doberman', 'miniature_pinscher', 'Greater_Swiss_Mountain_dog', 'Bernese_mountain_dog', 'Appenzeller', 'EntleBucher', 'boxer', 'bull_mastiff', 'Tibetan_mastiff', 'French_bulldog', 'Great_Dane', 'Saint_Bernard', 'Eskimo_dog', 'malamute', 'Siberian_husky', 'affenpinscher', 'basenji', 'pug', 'Leonberg', 'Newfoundland', 'Great_Pyrenees', 'Samoyed', 'Pomeranian', 'chow', 'keeshond', 'Brabancon_griffon', 'Pembroke', 'Cardigan', 'toy_poodle', 'miniature_poodle', 'standard_poodle', 'Mexican_hairless', 'dingo', 'dhole', 'African_hunting_dog']

# %%
if presplit:
    plot_images_per_class(images_path, mode='train', title='Distribution of Training Data per Class')
    plot_images_per_class(images_path, mode='val', title='Distribution of Validation Data per Class')
    try:
        plot_images_per_class(images_path, mode='test', title='Distribution of Testing Data per Class')
    except:
        pass
else:
    plot_images_per_class(images_path, mode='', title='Distribution of All Images per Class')

# %%
net_model = resnet.resnet152(pretrained=True)
net_name = 'resnet152'
unfrozen_layers = ['layer4', 'fc'] 

dropout_ratio = 0.9

net_model = load_network(net_model, net_name, dropout_ratio, class_names, unfrozen_layers)

print(f'Images in training set {len(training_set)}, validation set {len(validation_set)}, testing set {len(testing_set)}')
# Out:
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=ResNet152_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet152_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet152-394f9c45.pth" to /root/.cache/torch/hub/checkpoints/resnet152-394f9c45.pth
#   0%|          | 0.00/230M [00:00<?, ?B/s]
# conv1 is frozen
# bn1 is frozen
# relu is frozen
# maxpool is frozen
# layer1 is frozen
# layer2 is frozen
# layer3 is frozen
# layer4 is unfrozen
# avgpool is frozen
# fc is unfrozen
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (6): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (7): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (6): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (7): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (8): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (9): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (10): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (11): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (12): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (13): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (14): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (15): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (16): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (17): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (18): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (19): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (20): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (21): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (22): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (23): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (24): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (25): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (26): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (27): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (28): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (29): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (30): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (31): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (32): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (33): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (34): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (35): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=2048, out_features=256, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.9, inplace=False)
#     (3): Linear(in_features=256, out_features=120, bias=True)
#   )
# )
# 58,699,192 total parameters
# 15,520,120 training parameters
# Images in training set 10290, validation set 5145, testing set 5145

# %%
plot_grid_images(training_set, batch_size, class_names, mean, std, rows=3, columns=3, size=10)

# %%
learning_rate = 0.0001
epochs = 100
momentum = 0.9
weight_decay = 0
patience = 3
n_epochs_stop = 5

net_model, loss_acc, y_testing, preds = train_model(results_path, net_name, net_model, training_set_loader, validation_set_loader, 
                                                    learning_rate, epochs, momentum, weight_decay, patience, n_epochs_stop)
# Out:
# Using 1 GPUs
# [train] Epoch 1/100 Iteration 1/81 Loss: 4.91 Accuracy: 0.00
# [train] Epoch 1/100 Iteration 17/81 Loss: 4.80 Accuracy: 0.01
# [train] Epoch 1/100 Iteration 33/81 Loss: 4.75 Accuracy: 0.01
# [train] Epoch 1/100 Iteration 49/81 Loss: 4.71 Accuracy: 0.02
# [train] Epoch 1/100 Iteration 65/81 Loss: 4.65 Accuracy: 0.03
# [train] Epoch 1/100 Iteration 81/81 Loss: 4.60 Accuracy: 0.03
# [train] Epoch 1/100 Iteration 81/81 Loss: 4.60 Accuracy: 0.03
# [val] Epoch 1/100 Iteration 1/41 Loss: 4.13 Accuracy: 0.46
# [val] Epoch 1/100 Iteration 9/41 Loss: 4.07 Accuracy: 0.46
# [val] Epoch 1/100 Iteration 17/41 Loss: 4.07 Accuracy: 0.46
# [val] Epoch 1/100 Iteration 25/41 Loss: 4.07 Accuracy: 0.47
# [val] Epoch 1/100 Iteration 33/41 Loss: 4.08 Accuracy: 0.47
# [val] Epoch 1/100 Iteration 41/41 Loss: 4.07 Accuracy: 0.48
# [val] Epoch 1/100 Iteration 41/41 Loss: 4.07 Accuracy: 0.48
# [train] Epoch 2/100 Iteration 1/81 Loss: 4.27 Accuracy: 0.07
# [train] Epoch 2/100 Iteration 17/81 Loss: 4.18 Accuracy: 0.09
# [train] Epoch 2/100 Iteration 33/81 Loss: 4.13 Accuracy: 0.11
# [train] Epoch 2/100 Iteration 49/81 Loss: 4.06 Accuracy: 0.12
# [train] Epoch 2/100 Iteration 65/81 Loss: 4.00 Accuracy: 0.13
# [train] Epoch 2/100 Iteration 81/81 Loss: 3.95 Accuracy: 0.14
# [train] Epoch 2/100 Iteration 81/81 Loss: 3.95 Accuracy: 0.14
# [val] Epoch 2/100 Iteration 1/41 Loss: 3.14 Accuracy: 0.59
# [val] Epoch 2/100 Iteration 9/41 Loss: 3.15 Accuracy: 0.59
# [val] Epoch 2/100 Iteration 17/41 Loss: 3.15 Accuracy: 0.59
# [val] Epoch 2/100 Iteration 25/41 Loss: 3.15 Accuracy: 0.60
# [val] Epoch 2/100 Iteration 33/41 Loss: 3.15 Accuracy: 0.60
# [val] Epoch 2/100 Iteration 41/41 Loss: 3.15 Accuracy: 0.60
# [val] Epoch 2/100 Iteration 41/41 Loss: 3.15 Accuracy: 0.60
# [train] Epoch 3/100 Iteration 1/81 Loss: 3.46 Accuracy: 0.27
# [train] Epoch 3/100 Iteration 17/81 Loss: 3.53 Accuracy: 0.21
# [train] Epoch 3/100 Iteration 33/81 Loss: 3.45 Accuracy: 0.23
# [train] Epoch 3/100 Iteration 49/81 Loss: 3.40 Accuracy: 0.24
# [train] Epoch 3/100 Iteration 65/81 Loss: 3.37 Accuracy: 0.24
# [train] Epoch 3/100 Iteration 81/81 Loss: 3.32 Accuracy: 0.25
# [train] Epoch 3/100 Iteration 81/81 Loss: 3.32 Accuracy: 0.25
# [val] Epoch 3/100 Iteration 1/41 Loss: 2.35 Accuracy: 0.67
# [val] Epoch 3/100 Iteration 9/41 Loss: 2.34 Accuracy: 0.69
# [val] Epoch 3/100 Iteration 17/41 Loss: 2.34 Accuracy: 0.69
# [val] Epoch 3/100 Iteration 25/41 Loss: 2.35 Accuracy: 0.69
# [val] Epoch 3/100 Iteration 33/41 Loss: 2.36 Accuracy: 0.68
# [val] Epoch 3/100 Iteration 41/41 Loss: 2.38 Accuracy: 0.68
# [val] Epoch 3/100 Iteration 41/41 Loss: 2.38 Accuracy: 0.68
# [train] Epoch 4/100 Iteration 1/81 Loss: 2.83 Accuracy: 0.33
# [train] Epoch 4/100 Iteration 17/81 Loss: 2.95 Accuracy: 0.32
# [train] Epoch 4/100 Iteration 33/81 Loss: 2.92 Accuracy: 0.33
# [train] Epoch 4/100 Iteration 49/81 Loss: 2.89 Accuracy: 0.33
# [train] Epoch 4/100 Iteration 65/81 Loss: 2.86 Accuracy: 0.34
# [train] Epoch 4/100 Iteration 81/81 Loss: 2.81 Accuracy: 0.35
# [train] Epoch 4/100 Iteration 81/81 Loss: 2.81 Accuracy: 0.35
# [val] Epoch 4/100 Iteration 1/41 Loss: 1.61 Accuracy: 0.78
# [val] Epoch 4/100 Iteration 9/41 Loss: 1.76 Accuracy: 0.72
# [val] Epoch 4/100 Iteration 17/41 Loss: 1.75 Accuracy: 0.72
# [val] Epoch 4/100 Iteration 25/41 Loss: 1.80 Accuracy: 0.72
# [val] Epoch 4/100 Iteration 33/41 Loss: 1.79 Accuracy: 0.72
# [val] Epoch 4/100 Iteration 41/41 Loss: 1.80 Accuracy: 0.71
# [val] Epoch 4/100 Iteration 41/41 Loss: 1.80 Accuracy: 0.71
# [train] Epoch 5/100 Iteration 1/81 Loss: 2.62 Accuracy: 0.35
# [train] Epoch 5/100 Iteration 17/81 Loss: 2.51 Accuracy: 0.41
# [train] Epoch 5/100 Iteration 33/81 Loss: 2.51 Accuracy: 0.40
# [train] Epoch 5/100 Iteration 49/81 Loss: 2.49 Accuracy: 0.41
# [train] Epoch 5/100 Iteration 65/81 Loss: 2.46 Accuracy: 0.42
# [train] Epoch 5/100 Iteration 81/81 Loss: 2.42 Accuracy: 0.43
# [train] Epoch 5/100 Iteration 81/81 Loss: 2.42 Accuracy: 0.43
# [val] Epoch 5/100 Iteration 1/41 Loss: 1.55 Accuracy: 0.74
# [val] Epoch 5/100 Iteration 9/41 Loss: 1.44 Accuracy: 0.77
# [val] Epoch 5/100 Iteration 17/41 Loss: 1.42 Accuracy: 0.77
# [val] Epoch 5/100 Iteration 25/41 Loss: 1.44 Accuracy: 0.76
# [val] Epoch 5/100 Iteration 33/41 Loss: 1.46 Accuracy: 0.75
# [val] Epoch 5/100 Iteration 41/41 Loss: 1.46 Accuracy: 0.75
# [val] Epoch 5/100 Iteration 41/41 Loss: 1.46 Accuracy: 0.75
# [train] Epoch 6/100 Iteration 1/81 Loss: 2.28 Accuracy: 0.48
# [train] Epoch 6/100 Iteration 17/81 Loss: 2.18 Accuracy: 0.48
# [train] Epoch 6/100 Iteration 33/81 Loss: 2.15 Accuracy: 0.48
# [train] Epoch 6/100 Iteration 49/81 Loss: 2.12 Accuracy: 0.49
# [train] Epoch 6/100 Iteration 65/81 Loss: 2.09 Accuracy: 0.49
# [train] Epoch 6/100 Iteration 81/81 Loss: 2.08 Accuracy: 0.50
# [train] Epoch 6/100 Iteration 81/81 Loss: 2.08 Accuracy: 0.50
# [val] Epoch 6/100 Iteration 1/41 Loss: 1.11 Accuracy: 0.80
# [val] Epoch 6/100 Iteration 9/41 Loss: 1.26 Accuracy: 0.77
# [val] Epoch 6/100 Iteration 17/41 Loss: 1.23 Accuracy: 0.77
# [val] Epoch 6/100 Iteration 25/41 Loss: 1.26 Accuracy: 0.77
# [val] Epoch 6/100 Iteration 33/41 Loss: 1.27 Accuracy: 0.77
# [val] Epoch 6/100 Iteration 41/41 Loss: 1.28 Accuracy: 0.77
# [val] Epoch 6/100 Iteration 41/41 Loss: 1.28 Accuracy: 0.77
# [train] Epoch 7/100 Iteration 1/81 Loss: 1.96 Accuracy: 0.52
# [train] Epoch 7/100 Iteration 17/81 Loss: 1.89 Accuracy: 0.54
# [train] Epoch 7/100 Iteration 33/81 Loss: 1.86 Accuracy: 0.55
# [train] Epoch 7/100 Iteration 49/81 Loss: 1.86 Accuracy: 0.55
# [train] Epoch 7/100 Iteration 65/81 Loss: 1.83 Accuracy: 0.55
# [train] Epoch 7/100 Iteration 81/81 Loss: 1.82 Accuracy: 0.56
# [train] Epoch 7/100 Iteration 81/81 Loss: 1.82 Accuracy: 0.56
# [val] Epoch 7/100 Iteration 1/41 Loss: 1.20 Accuracy: 0.78
# [val] Epoch 7/100 Iteration 9/41 Loss: 1.07 Accuracy: 0.80
# [val] Epoch 7/100 Iteration 17/41 Loss: 1.10 Accuracy: 0.78
# [val] Epoch 7/100 Iteration 25/41 Loss: 1.08 Accuracy: 0.78
# [val] Epoch 7/100 Iteration 33/41 Loss: 1.07 Accuracy: 0.78
# [val] Epoch 7/100 Iteration 41/41 Loss: 1.07 Accuracy: 0.78
# [val] Epoch 7/100 Iteration 41/41 Loss: 1.07 Accuracy: 0.78
# [train] Epoch 8/100 Iteration 1/81 Loss: 1.74 Accuracy: 0.56
# [train] Epoch 8/100 Iteration 17/81 Loss: 1.61 Accuracy: 0.60
# [train] Epoch 8/100 Iteration 33/81 Loss: 1.62 Accuracy: 0.59
# [train] Epoch 8/100 Iteration 49/81 Loss: 1.60 Accuracy: 0.60
# [train] Epoch 8/100 Iteration 65/81 Loss: 1.58 Accuracy: 0.61
# [train] Epoch 8/100 Iteration 81/81 Loss: 1.56 Accuracy: 0.61
# [train] Epoch 8/100 Iteration 81/81 Loss: 1.56 Accuracy: 0.61
# [val] Epoch 8/100 Iteration 1/41 Loss: 0.78 Accuracy: 0.84
# [val] Epoch 8/100 Iteration 9/41 Loss: 0.93 Accuracy: 0.80
# [val] Epoch 8/100 Iteration 17/41 Loss: 0.92 Accuracy: 0.81
# [val] Epoch 8/100 Iteration 25/41 Loss: 0.92 Accuracy: 0.80
# [val] Epoch 8/100 Iteration 33/41 Loss: 0.92 Accuracy: 0.80
# [val] Epoch 8/100 Iteration 41/41 Loss: 0.93 Accuracy: 0.80
# [val] Epoch 8/100 Iteration 41/41 Loss: 0.93 Accuracy: 0.80
# [train] Epoch 9/100 Iteration 1/81 Loss: 1.44 Accuracy: 0.66
# [train] Epoch 9/100 Iteration 17/81 Loss: 1.44 Accuracy: 0.63
# [train] Epoch 9/100 Iteration 33/81 Loss: 1.41 Accuracy: 0.64
# [train] Epoch 9/100 Iteration 49/81 Loss: 1.39 Accuracy: 0.65
# [train] Epoch 9/100 Iteration 65/81 Loss: 1.38 Accuracy: 0.65
# [train] Epoch 9/100 Iteration 81/81 Loss: 1.37 Accuracy: 0.66
# [train] Epoch 9/100 Iteration 81/81 Loss: 1.37 Accuracy: 0.66
# [val] Epoch 9/100 Iteration 1/41 Loss: 0.79 Accuracy: 0.84
# [val] Epoch 9/100 Iteration 9/41 Loss: 0.84 Accuracy: 0.79
# [val] Epoch 9/100 Iteration 17/41 Loss: 0.85 Accuracy: 0.80
# [val] Epoch 9/100 Iteration 25/41 Loss: 0.85 Accuracy: 0.80
# [val] Epoch 9/100 Iteration 33/41 Loss: 0.85 Accuracy: 0.80
# [val] Epoch 9/100 Iteration 41/41 Loss: 0.84 Accuracy: 0.81
# [val] Epoch 9/100 Iteration 41/41 Loss: 0.84 Accuracy: 0.81
# [train] Epoch 10/100 Iteration 1/81 Loss: 1.16 Accuracy: 0.72
# [train] Epoch 10/100 Iteration 17/81 Loss: 1.21 Accuracy: 0.70
# [train] Epoch 10/100 Iteration 33/81 Loss: 1.22 Accuracy: 0.69
# [train] Epoch 10/100 Iteration 49/81 Loss: 1.21 Accuracy: 0.70
# [train] Epoch 10/100 Iteration 65/81 Loss: 1.21 Accuracy: 0.70
# [train] Epoch 10/100 Iteration 81/81 Loss: 1.19 Accuracy: 0.70
# [train] Epoch 10/100 Iteration 81/81 Loss: 1.19 Accuracy: 0.70
# [val] Epoch 10/100 Iteration 1/41 Loss: 0.88 Accuracy: 0.80
# [val] Epoch 10/100 Iteration 9/41 Loss: 0.77 Accuracy: 0.82
# [val] Epoch 10/100 Iteration 17/41 Loss: 0.77 Accuracy: 0.81
# [val] Epoch 10/100 Iteration 25/41 Loss: 0.79 Accuracy: 0.81
# [val] Epoch 10/100 Iteration 33/41 Loss: 0.79 Accuracy: 0.81
# [val] Epoch 10/100 Iteration 41/41 Loss: 0.79 Accuracy: 0.81
# [val] Epoch 10/100 Iteration 41/41 Loss: 0.79 Accuracy: 0.81
# [train] Epoch 11/100 Iteration 1/81 Loss: 1.15 Accuracy: 0.71
# [train] Epoch 11/100 Iteration 17/81 Loss: 1.11 Accuracy: 0.72
# [train] Epoch 11/100 Iteration 33/81 Loss: 1.09 Accuracy: 0.72
# [train] Epoch 11/100 Iteration 49/81 Loss: 1.09 Accuracy: 0.72
# [train] Epoch 11/100 Iteration 65/81 Loss: 1.08 Accuracy: 0.72
# [train] Epoch 11/100 Iteration 81/81 Loss: 1.07 Accuracy: 0.72
# [train] Epoch 11/100 Iteration 81/81 Loss: 1.07 Accuracy: 0.72
# [val] Epoch 11/100 Iteration 1/41 Loss: 0.90 Accuracy: 0.74
# [val] Epoch 11/100 Iteration 9/41 Loss: 0.83 Accuracy: 0.78
# [val] Epoch 11/100 Iteration 17/41 Loss: 0.80 Accuracy: 0.79
# [val] Epoch 11/100 Iteration 25/41 Loss: 0.79 Accuracy: 0.80
# [val] Epoch 11/100 Iteration 33/41 Loss: 0.79 Accuracy: 0.80
# [val] Epoch 11/100 Iteration 41/41 Loss: 0.78 Accuracy: 0.80
# [val] Epoch 11/100 Iteration 41/41 Loss: 0.78 Accuracy: 0.80
# [train] Epoch 12/100 Iteration 1/81 Loss: 1.13 Accuracy: 0.69
# [train] Epoch 12/100 Iteration 17/81 Loss: 0.95 Accuracy: 0.76
# [train] Epoch 12/100 Iteration 33/81 Loss: 0.97 Accuracy: 0.75
# [train] Epoch 12/100 Iteration 49/81 Loss: 0.95 Accuracy: 0.75
# [train] Epoch 12/100 Iteration 65/81 Loss: 0.93 Accuracy: 0.76
# [train] Epoch 12/100 Iteration 81/81 Loss: 0.94 Accuracy: 0.76
# [train] Epoch 12/100 Iteration 81/81 Loss: 0.94 Accuracy: 0.76
# [val] Epoch 12/100 Iteration 1/41 Loss: 0.93 Accuracy: 0.78
# [val] Epoch 12/100 Iteration 9/41 Loss: 0.69 Accuracy: 0.82
# [val] Epoch 12/100 Iteration 17/41 Loss: 0.70 Accuracy: 0.81
# [val] Epoch 12/100 Iteration 25/41 Loss: 0.69 Accuracy: 0.82
# [val] Epoch 12/100 Iteration 33/41 Loss: 0.71 Accuracy: 0.81
# [val] Epoch 12/100 Iteration 41/41 Loss: 0.71 Accuracy: 0.81
# [val] Epoch 12/100 Iteration 41/41 Loss: 0.71 Accuracy: 0.81
# [train] Epoch 13/100 Iteration 1/81 Loss: 0.81 Accuracy: 0.77
# [train] Epoch 13/100 Iteration 17/81 Loss: 0.87 Accuracy: 0.76
# [train] Epoch 13/100 Iteration 33/81 Loss: 0.85 Accuracy: 0.77
# [train] Epoch 13/100 Iteration 49/81 Loss: 0.85 Accuracy: 0.77
# [train] Epoch 13/100 Iteration 65/81 Loss: 0.85 Accuracy: 0.77
# [train] Epoch 13/100 Iteration 81/81 Loss: 0.85 Accuracy: 0.77
# [train] Epoch 13/100 Iteration 81/81 Loss: 0.85 Accuracy: 0.77
# [val] Epoch 13/100 Iteration 1/41 Loss: 0.68 Accuracy: 0.84
# [val] Epoch 13/100 Iteration 9/41 Loss: 0.72 Accuracy: 0.81
# [val] Epoch 13/100 Iteration 17/41 Loss: 0.71 Accuracy: 0.82
# [val] Epoch 13/100 Iteration 25/41 Loss: 0.71 Accuracy: 0.82
# [val] Epoch 13/100 Iteration 33/41 Loss: 0.72 Accuracy: 0.81
# [val] Epoch 13/100 Iteration 41/41 Loss: 0.72 Accuracy: 0.81
# [val] Epoch 13/100 Iteration 41/41 Loss: 0.72 Accuracy: 0.81
# Epochs with no improvement 1
# [train] Epoch 14/100 Iteration 1/81 Loss: 0.89 Accuracy: 0.77
# [train] Epoch 14/100 Iteration 17/81 Loss: 0.85 Accuracy: 0.78
# [train] Epoch 14/100 Iteration 33/81 Loss: 0.85 Accuracy: 0.78
# [train] Epoch 14/100 Iteration 49/81 Loss: 0.85 Accuracy: 0.78
# [train] Epoch 14/100 Iteration 65/81 Loss: 0.84 Accuracy: 0.78
# [train] Epoch 14/100 Iteration 81/81 Loss: 0.84 Accuracy: 0.78
# [train] Epoch 14/100 Iteration 81/81 Loss: 0.84 Accuracy: 0.78
# [val] Epoch 14/100 Iteration 1/41 Loss: 0.61 Accuracy: 0.82
# [val] Epoch 14/100 Iteration 9/41 Loss: 0.71 Accuracy: 0.82
# [val] Epoch 14/100 Iteration 17/41 Loss: 0.71 Accuracy: 0.81
# [val] Epoch 14/100 Iteration 25/41 Loss: 0.70 Accuracy: 0.82
# [val] Epoch 14/100 Iteration 33/41 Loss: 0.70 Accuracy: 0.82
# [val] Epoch 14/100 Iteration 41/41 Loss: 0.70 Accuracy: 0.82
# [val] Epoch 14/100 Iteration 41/41 Loss: 0.70 Accuracy: 0.82
# [train] Epoch 15/100 Iteration 1/81 Loss: 0.67 Accuracy: 0.81
# [train] Epoch 15/100 Iteration 17/81 Loss: 0.75 Accuracy: 0.81
# [train] Epoch 15/100 Iteration 33/81 Loss: 0.75 Accuracy: 0.80
# [train] Epoch 15/100 Iteration 49/81 Loss: 0.75 Accuracy: 0.80
# [train] Epoch 15/100 Iteration 65/81 Loss: 0.75 Accuracy: 0.80
# [train] Epoch 15/100 Iteration 81/81 Loss: 0.75 Accuracy: 0.80
# [train] Epoch 15/100 Iteration 81/81 Loss: 0.75 Accuracy: 0.80
# [val] Epoch 15/100 Iteration 1/41 Loss: 0.80 Accuracy: 0.80
# [val] Epoch 15/100 Iteration 9/41 Loss: 0.74 Accuracy: 0.80
# [val] Epoch 15/100 Iteration 17/41 Loss: 0.73 Accuracy: 0.81
# [val] Epoch 15/100 Iteration 25/41 Loss: 0.71 Accuracy: 0.81
# [val] Epoch 15/100 Iteration 33/41 Loss: 0.71 Accuracy: 0.81
# [val] Epoch 15/100 Iteration 41/41 Loss: 0.70 Accuracy: 0.81
# [val] Epoch 15/100 Iteration 41/41 Loss: 0.70 Accuracy: 0.81
# Epochs with no improvement 1
# [train] Epoch 16/100 Iteration 1/81 Loss: 0.68 Accuracy: 0.81
# [train] Epoch 16/100 Iteration 17/81 Loss: 0.77 Accuracy: 0.79
# [train] Epoch 16/100 Iteration 33/81 Loss: 0.76 Accuracy: 0.79
# [train] Epoch 16/100 Iteration 49/81 Loss: 0.76 Accuracy: 0.80
# [train] Epoch 16/100 Iteration 65/81 Loss: 0.76 Accuracy: 0.80
# [train] Epoch 16/100 Iteration 81/81 Loss: 0.76 Accuracy: 0.80
# [train] Epoch 16/100 Iteration 81/81 Loss: 0.76 Accuracy: 0.80
# [val] Epoch 16/100 Iteration 1/41 Loss: 0.83 Accuracy: 0.81
# [val] Epoch 16/100 Iteration 9/41 Loss: 0.65 Accuracy: 0.83
# [val] Epoch 16/100 Iteration 17/41 Loss: 0.67 Accuracy: 0.83
# [val] Epoch 16/100 Iteration 25/41 Loss: 0.68 Accuracy: 0.82
# [val] Epoch 16/100 Iteration 33/41 Loss: 0.68 Accuracy: 0.82
# [val] Epoch 16/100 Iteration 41/41 Loss: 0.68 Accuracy: 0.82
# [val] Epoch 16/100 Iteration 41/41 Loss: 0.68 Accuracy: 0.82
# [train] Epoch 17/100 Iteration 1/81 Loss: 0.73 Accuracy: 0.81
# [train] Epoch 17/100 Iteration 17/81 Loss: 0.70 Accuracy: 0.82
# [train] Epoch 17/100 Iteration 33/81 Loss: 0.73 Accuracy: 0.81
# [train] Epoch 17/100 Iteration 49/81 Loss: 0.72 Accuracy: 0.81
# [train] Epoch 17/100 Iteration 65/81 Loss: 0.71 Accuracy: 0.81
# [train] Epoch 17/100 Iteration 81/81 Loss: 0.70 Accuracy: 0.81
# [train] Epoch 17/100 Iteration 81/81 Loss: 0.70 Accuracy: 0.81
# [val] Epoch 17/100 Iteration 1/41 Loss: 0.50 Accuracy: 0.87
# [val] Epoch 17/100 Iteration 9/41 Loss: 0.70 Accuracy: 0.81
# [val] Epoch 17/100 Iteration 17/41 Loss: 0.66 Accuracy: 0.83
# [val] Epoch 17/100 Iteration 25/41 Loss: 0.68 Accuracy: 0.82
# [val] Epoch 17/100 Iteration 33/41 Loss: 0.68 Accuracy: 0.82
# [val] Epoch 17/100 Iteration 41/41 Loss: 0.68 Accuracy: 0.82
# [val] Epoch 17/100 Iteration 41/41 Loss: 0.68 Accuracy: 0.82
# [train] Epoch 18/100 Iteration 1/81 Loss: 0.61 Accuracy: 0.84
# [train] Epoch 18/100 Iteration 17/81 Loss: 0.65 Accuracy: 0.83
# [train] Epoch 18/100 Iteration 33/81 Loss: 0.65 Accuracy: 0.83
# [train] Epoch 18/100 Iteration 49/81 Loss: 0.65 Accuracy: 0.83
# [train] Epoch 18/100 Iteration 65/81 Loss: 0.65 Accuracy: 0.82
# [train] Epoch 18/100 Iteration 81/81 Loss: 0.64 Accuracy: 0.83
# [train] Epoch 18/100 Iteration 81/81 Loss: 0.64 Accuracy: 0.83
# [val] Epoch 18/100 Iteration 1/41 Loss: 0.60 Accuracy: 0.85
# [val] Epoch 18/100 Iteration 9/41 Loss: 0.68 Accuracy: 0.82
# [val] Epoch 18/100 Iteration 17/41 Loss: 0.72 Accuracy: 0.81
# [val] Epoch 18/100 Iteration 25/41 Loss: 0.72 Accuracy: 0.81
# [val] Epoch 18/100 Iteration 33/41 Loss: 0.73 Accuracy: 0.81
# [val] Epoch 18/100 Iteration 41/41 Loss: 0.74 Accuracy: 0.81
# [val] Epoch 18/100 Iteration 41/41 Loss: 0.74 Accuracy: 0.81
# Epochs with no improvement 1
# [train] Epoch 19/100 Iteration 1/81 Loss: 0.61 Accuracy: 0.83
# [train] Epoch 19/100 Iteration 17/81 Loss: 0.64 Accuracy: 0.82
# [train] Epoch 19/100 Iteration 33/81 Loss: 0.64 Accuracy: 0.82
# [train] Epoch 19/100 Iteration 49/81 Loss: 0.64 Accuracy: 0.82
# [train] Epoch 19/100 Iteration 65/81 Loss: 0.63 Accuracy: 0.82
# [train] Epoch 19/100 Iteration 81/81 Loss: 0.62 Accuracy: 0.82
# [train] Epoch 19/100 Iteration 81/81 Loss: 0.62 Accuracy: 0.82
# [val] Epoch 19/100 Iteration 1/41 Loss: 0.59 Accuracy: 0.83
# [val] Epoch 19/100 Iteration 9/41 Loss: 0.75 Accuracy: 0.79
# [val] Epoch 19/100 Iteration 17/41 Loss: 0.72 Accuracy: 0.81
# [val] Epoch 19/100 Iteration 25/41 Loss: 0.72 Accuracy: 0.81
# [val] Epoch 19/100 Iteration 33/41 Loss: 0.70 Accuracy: 0.82
# [val] Epoch 19/100 Iteration 41/41 Loss: 0.70 Accuracy: 0.82
# [val] Epoch 19/100 Iteration 41/41 Loss: 0.70 Accuracy: 0.82
# Epochs with no improvement 2
# [train] Epoch 20/100 Iteration 1/81 Loss: 0.72 Accuracy: 0.79
# [train] Epoch 20/100 Iteration 17/81 Loss: 0.65 Accuracy: 0.82
# [train] Epoch 20/100 Iteration 33/81 Loss: 0.65 Accuracy: 0.82
# [train] Epoch 20/100 Iteration 49/81 Loss: 0.64 Accuracy: 0.83
# [train] Epoch 20/100 Iteration 65/81 Loss: 0.63 Accuracy: 0.83
# [train] Epoch 20/100 Iteration 81/81 Loss: 0.63 Accuracy: 0.83
# [train] Epoch 20/100 Iteration 81/81 Loss: 0.63 Accuracy: 0.83
# [val] Epoch 20/100 Iteration 1/41 Loss: 0.66 Accuracy: 0.81
# [val] Epoch 20/100 Iteration 9/41 Loss: 0.67 Accuracy: 0.82
# [val] Epoch 20/100 Iteration 17/41 Loss: 0.70 Accuracy: 0.82
# [val] Epoch 20/100 Iteration 25/41 Loss: 0.70 Accuracy: 0.82
# [val] Epoch 20/100 Iteration 33/41 Loss: 0.71 Accuracy: 0.81
# [val] Epoch 20/100 Iteration 41/41 Loss: 0.70 Accuracy: 0.82
# [val] Epoch 20/100 Iteration 41/41 Loss: 0.70 Accuracy: 0.82
# Epochs with no improvement 3
# [train] Epoch 21/100 Iteration 1/81 Loss: 0.60 Accuracy: 0.83
# [train] Epoch 21/100 Iteration 17/81 Loss: 0.62 Accuracy: 0.84
# [train] Epoch 21/100 Iteration 33/81 Loss: 0.63 Accuracy: 0.83
# [train] Epoch 21/100 Iteration 49/81 Loss: 0.63 Accuracy: 0.83
# [train] Epoch 21/100 Iteration 65/81 Loss: 0.63 Accuracy: 0.84
# [train] Epoch 21/100 Iteration 81/81 Loss: 0.63 Accuracy: 0.83
# [train] Epoch 21/100 Iteration 81/81 Loss: 0.63 Accuracy: 0.83
# [val] Epoch 21/100 Iteration 1/41 Loss: 0.33 Accuracy: 0.88
# [val] Epoch 21/100 Iteration 9/41 Loss: 0.67 Accuracy: 0.82
# [val] Epoch 21/100 Iteration 17/41 Loss: 0.69 Accuracy: 0.83
# [val] Epoch 21/100 Iteration 25/41 Loss: 0.68 Accuracy: 0.83
# [val] Epoch 21/100 Iteration 33/41 Loss: 0.67 Accuracy: 0.82
# [val] Epoch 21/100 Iteration 41/41 Loss: 0.68 Accuracy: 0.82
# [val] Epoch 21/100 Iteration 41/41 Loss: 0.68 Accuracy: 0.82
# Epoch 00021: reducing learning rate of group 0 to 1.0000e-05.
# Epochs with no improvement 4
# [train] Epoch 22/100 Iteration 1/81 Loss: 0.64 Accuracy: 0.81
# [train] Epoch 22/100 Iteration 17/81 Loss: 0.63 Accuracy: 0.83
# [train] Epoch 22/100 Iteration 33/81 Loss: 0.63 Accuracy: 0.83
# [train] Epoch 22/100 Iteration 49/81 Loss: 0.63 Accuracy: 0.83
# [train] Epoch 22/100 Iteration 65/81 Loss: 0.63 Accuracy: 0.83
# [train] Epoch 22/100 Iteration 81/81 Loss: 0.62 Accuracy: 0.83
# [train] Epoch 22/100 Iteration 81/81 Loss: 0.62 Accuracy: 0.83
# [val] Epoch 22/100 Iteration 1/41 Loss: 0.67 Accuracy: 0.80
# [val] Epoch 22/100 Iteration 9/41 Loss: 0.62 Accuracy: 0.83
# [val] Epoch 22/100 Iteration 17/41 Loss: 0.64 Accuracy: 0.83
# [val] Epoch 22/100 Iteration 25/41 Loss: 0.62 Accuracy: 0.83
# [val] Epoch 22/100 Iteration 33/41 Loss: 0.61 Accuracy: 0.83
# [val] Epoch 22/100 Iteration 41/41 Loss: 0.61 Accuracy: 0.83
# [val] Epoch 22/100 Iteration 41/41 Loss: 0.61 Accuracy: 0.83
# [train] Epoch 23/100 Iteration 1/81 Loss: 0.60 Accuracy: 0.88
# [train] Epoch 23/100 Iteration 17/81 Loss: 0.60 Accuracy: 0.84
# [train] Epoch 23/100 Iteration 33/81 Loss: 0.60 Accuracy: 0.84
# [train] Epoch 23/100 Iteration 49/81 Loss: 0.59 Accuracy: 0.84
# [train] Epoch 23/100 Iteration 65/81 Loss: 0.60 Accuracy: 0.84
# [train] Epoch 23/100 Iteration 81/81 Loss: 0.59 Accuracy: 0.84
# [train] Epoch 23/100 Iteration 81/81 Loss: 0.59 Accuracy: 0.84
# [val] Epoch 23/100 Iteration 1/41 Loss: 0.49 Accuracy: 0.88
# [val] Epoch 23/100 Iteration 9/41 Loss: 0.59 Accuracy: 0.84
# [val] Epoch 23/100 Iteration 17/41 Loss: 0.61 Accuracy: 0.84
# [val] Epoch 23/100 Iteration 25/41 Loss: 0.61 Accuracy: 0.84
# [val] Epoch 23/100 Iteration 33/41 Loss: 0.61 Accuracy: 0.84
# [val] Epoch 23/100 Iteration 41/41 Loss: 0.61 Accuracy: 0.84
# [val] Epoch 23/100 Iteration 41/41 Loss: 0.61 Accuracy: 0.84
# [train] Epoch 24/100 Iteration 1/81 Loss: 0.61 Accuracy: 0.84
# [train] Epoch 24/100 Iteration 17/81 Loss: 0.59 Accuracy: 0.84
# [train] Epoch 24/100 Iteration 33/81 Loss: 0.56 Accuracy: 0.85
# [train] Epoch 24/100 Iteration 49/81 Loss: 0.57 Accuracy: 0.85
# [train] Epoch 24/100 Iteration 65/81 Loss: 0.58 Accuracy: 0.84
# [train] Epoch 24/100 Iteration 81/81 Loss: 0.58 Accuracy: 0.84
# [train] Epoch 24/100 Iteration 81/81 Loss: 0.58 Accuracy: 0.84
# [val] Epoch 24/100 Iteration 1/41 Loss: 0.50 Accuracy: 0.82
# [val] Epoch 24/100 Iteration 9/41 Loss: 0.55 Accuracy: 0.85
# [val] Epoch 24/100 Iteration 17/41 Loss: 0.58 Accuracy: 0.84
# [val] Epoch 24/100 Iteration 25/41 Loss: 0.58 Accuracy: 0.84
# [val] Epoch 24/100 Iteration 33/41 Loss: 0.60 Accuracy: 0.84
# [val] Epoch 24/100 Iteration 41/41 Loss: 0.60 Accuracy: 0.84
# [val] Epoch 24/100 Iteration 41/41 Loss: 0.60 Accuracy: 0.84
# [train] Epoch 25/100 Iteration 1/81 Loss: 0.48 Accuracy: 0.89
# [train] Epoch 25/100 Iteration 17/81 Loss: 0.57 Accuracy: 0.85
# [train] Epoch 25/100 Iteration 33/81 Loss: 0.58 Accuracy: 0.85
# [train] Epoch 25/100 Iteration 49/81 Loss: 0.58 Accuracy: 0.84
# [train] Epoch 25/100 Iteration 65/81 Loss: 0.58 Accuracy: 0.85
# [train] Epoch 25/100 Iteration 81/81 Loss: 0.58 Accuracy: 0.84
# [train] Epoch 25/100 Iteration 81/81 Loss: 0.58 Accuracy: 0.84
# [val] Epoch 25/100 Iteration 1/41 Loss: 0.60 Accuracy: 0.82
# [val] Epoch 25/100 Iteration 9/41 Loss: 0.60 Accuracy: 0.84
# [val] Epoch 25/100 Iteration 17/41 Loss: 0.59 Accuracy: 0.85
# [val] Epoch 25/100 Iteration 25/41 Loss: 0.59 Accuracy: 0.85
# [val] Epoch 25/100 Iteration 33/41 Loss: 0.59 Accuracy: 0.85
# [val] Epoch 25/100 Iteration 41/41 Loss: 0.60 Accuracy: 0.84
# [val] Epoch 25/100 Iteration 41/41 Loss: 0.60 Accuracy: 0.84
# Epochs with no improvement 1
# [train] Epoch 26/100 Iteration 1/81 Loss: 0.51 Accuracy: 0.85
# [train] Epoch 26/100 Iteration 17/81 Loss: 0.60 Accuracy: 0.84
# [train] Epoch 26/100 Iteration 33/81 Loss: 0.59 Accuracy: 0.84
# [train] Epoch 26/100 Iteration 49/81 Loss: 0.59 Accuracy: 0.84
# [train] Epoch 26/100 Iteration 65/81 Loss: 0.59 Accuracy: 0.84
# [train] Epoch 26/100 Iteration 81/81 Loss: 0.59 Accuracy: 0.84
# [train] Epoch 26/100 Iteration 81/81 Loss: 0.59 Accuracy: 0.84
# [val] Epoch 26/100 Iteration 1/41 Loss: 0.78 Accuracy: 0.85
# [val] Epoch 26/100 Iteration 9/41 Loss: 0.62 Accuracy: 0.85
# [val] Epoch 26/100 Iteration 17/41 Loss: 0.64 Accuracy: 0.84
# [val] Epoch 26/100 Iteration 25/41 Loss: 0.62 Accuracy: 0.84
# [val] Epoch 26/100 Iteration 33/41 Loss: 0.62 Accuracy: 0.84
# [val] Epoch 26/100 Iteration 41/41 Loss: 0.62 Accuracy: 0.84
# [val] Epoch 26/100 Iteration 41/41 Loss: 0.62 Accuracy: 0.84
# Epochs with no improvement 2
# [train] Epoch 27/100 Iteration 1/81 Loss: 0.40 Accuracy: 0.89
# [train] Epoch 27/100 Iteration 17/81 Loss: 0.57 Accuracy: 0.85
# [train] Epoch 27/100 Iteration 33/81 Loss: 0.59 Accuracy: 0.84
# [train] Epoch 27/100 Iteration 49/81 Loss: 0.57 Accuracy: 0.84
# [train] Epoch 27/100 Iteration 65/81 Loss: 0.58 Accuracy: 0.84
# [train] Epoch 27/100 Iteration 81/81 Loss: 0.58 Accuracy: 0.84
# [train] Epoch 27/100 Iteration 81/81 Loss: 0.58 Accuracy: 0.84
# [val] Epoch 27/100 Iteration 1/41 Loss: 0.53 Accuracy: 0.88
# [val] Epoch 27/100 Iteration 9/41 Loss: 0.59 Accuracy: 0.84
# [val] Epoch 27/100 Iteration 17/41 Loss: 0.60 Accuracy: 0.85
# [val] Epoch 27/100 Iteration 25/41 Loss: 0.62 Accuracy: 0.84
# [val] Epoch 27/100 Iteration 33/41 Loss: 0.61 Accuracy: 0.84
# [val] Epoch 27/100 Iteration 41/41 Loss: 0.61 Accuracy: 0.84
# [val] Epoch 27/100 Iteration 41/41 Loss: 0.61 Accuracy: 0.84
# Epochs with no improvement 3
# [train] Epoch 28/100 Iteration 1/81 Loss: 0.65 Accuracy: 0.85
# [train] Epoch 28/100 Iteration 17/81 Loss: 0.58 Accuracy: 0.84
# [train] Epoch 28/100 Iteration 33/81 Loss: 0.57 Accuracy: 0.85
# [train] Epoch 28/100 Iteration 49/81 Loss: 0.58 Accuracy: 0.84
# [train] Epoch 28/100 Iteration 65/81 Loss: 0.58 Accuracy: 0.85
# [train] Epoch 28/100 Iteration 81/81 Loss: 0.58 Accuracy: 0.84
# [train] Epoch 28/100 Iteration 81/81 Loss: 0.58 Accuracy: 0.84
# [val] Epoch 28/100 Iteration 1/41 Loss: 0.70 Accuracy: 0.84
# [val] Epoch 28/100 Iteration 9/41 Loss: 0.65 Accuracy: 0.82
# [val] Epoch 28/100 Iteration 17/41 Loss: 0.65 Accuracy: 0.83
# [val] Epoch 28/100 Iteration 25/41 Loss: 0.63 Accuracy: 0.83
# [val] Epoch 28/100 Iteration 33/41 Loss: 0.61 Accuracy: 0.84
# [val] Epoch 28/100 Iteration 41/41 Loss: 0.61 Accuracy: 0.84
# [val] Epoch 28/100 Iteration 41/41 Loss: 0.61 Accuracy: 0.84
# Epoch 00028: reducing learning rate of group 0 to 1.0000e-06.
# Epochs with no improvement 4
# [train] Epoch 29/100 Iteration 1/81 Loss: 0.55 Accuracy: 0.88
# [train] Epoch 29/100 Iteration 17/81 Loss: 0.57 Accuracy: 0.86
# [train] Epoch 29/100 Iteration 33/81 Loss: 0.57 Accuracy: 0.84
# [train] Epoch 29/100 Iteration 49/81 Loss: 0.57 Accuracy: 0.85
# [train] Epoch 29/100 Iteration 65/81 Loss: 0.58 Accuracy: 0.84
# [train] Epoch 29/100 Iteration 81/81 Loss: 0.58 Accuracy: 0.84
# [train] Epoch 29/100 Iteration 81/81 Loss: 0.58 Accuracy: 0.84
# [val] Epoch 29/100 Iteration 1/41 Loss: 0.68 Accuracy: 0.79
# [val] Epoch 29/100 Iteration 9/41 Loss: 0.57 Accuracy: 0.83
# [val] Epoch 29/100 Iteration 17/41 Loss: 0.57 Accuracy: 0.84
# [val] Epoch 29/100 Iteration 25/41 Loss: 0.60 Accuracy: 0.83
# [val] Epoch 29/100 Iteration 33/41 Loss: 0.59 Accuracy: 0.84
# [val] Epoch 29/100 Iteration 41/41 Loss: 0.60 Accuracy: 0.84
# [val] Epoch 29/100 Iteration 41/41 Loss: 0.60 Accuracy: 0.84
# [train] Epoch 30/100 Iteration 1/81 Loss: 0.59 Accuracy: 0.87
# [train] Epoch 30/100 Iteration 17/81 Loss: 0.57 Accuracy: 0.84
# [train] Epoch 30/100 Iteration 33/81 Loss: 0.58 Accuracy: 0.84
# [train] Epoch 30/100 Iteration 49/81 Loss: 0.57 Accuracy: 0.84
# [train] Epoch 30/100 Iteration 65/81 Loss: 0.57 Accuracy: 0.84
# [train] Epoch 30/100 Iteration 81/81 Loss: 0.58 Accuracy: 0.84
# [train] Epoch 30/100 Iteration 81/81 Loss: 0.58 Accuracy: 0.84
# [val] Epoch 30/100 Iteration 1/41 Loss: 0.58 Accuracy: 0.86
# [val] Epoch 30/100 Iteration 9/41 Loss: 0.59 Accuracy: 0.84
# [val] Epoch 30/100 Iteration 17/41 Loss: 0.59 Accuracy: 0.84
# [val] Epoch 30/100 Iteration 25/41 Loss: 0.58 Accuracy: 0.84
# [val] Epoch 30/100 Iteration 33/41 Loss: 0.60 Accuracy: 0.84
# [val] Epoch 30/100 Iteration 41/41 Loss: 0.60 Accuracy: 0.84
# [val] Epoch 30/100 Iteration 41/41 Loss: 0.60 Accuracy: 0.84
# Epochs with no improvement 1
# [train] Epoch 31/100 Iteration 1/81 Loss: 0.67 Accuracy: 0.78
# [train] Epoch 31/100 Iteration 17/81 Loss: 0.56 Accuracy: 0.85
# [train] Epoch 31/100 Iteration 33/81 Loss: 0.57 Accuracy: 0.85
# [train] Epoch 31/100 Iteration 49/81 Loss: 0.56 Accuracy: 0.85
# [train] Epoch 31/100 Iteration 65/81 Loss: 0.57 Accuracy: 0.85
# [train] Epoch 31/100 Iteration 81/81 Loss: 0.56 Accuracy: 0.85
# [train] Epoch 31/100 Iteration 81/81 Loss: 0.56 Accuracy: 0.85
# [val] Epoch 31/100 Iteration 1/41 Loss: 0.68 Accuracy: 0.81
# [val] Epoch 31/100 Iteration 9/41 Loss: 0.61 Accuracy: 0.84
# [val] Epoch 31/100 Iteration 17/41 Loss: 0.62 Accuracy: 0.84
# [val] Epoch 31/100 Iteration 25/41 Loss: 0.61 Accuracy: 0.84
# [val] Epoch 31/100 Iteration 33/41 Loss: 0.62 Accuracy: 0.84
# [val] Epoch 31/100 Iteration 41/41 Loss: 0.61 Accuracy: 0.84
# [val] Epoch 31/100 Iteration 41/41 Loss: 0.61 Accuracy: 0.84
# Epochs with no improvement 2
# [train] Epoch 32/100 Iteration 1/81 Loss: 0.69 Accuracy: 0.78
# [train] Epoch 32/100 Iteration 17/81 Loss: 0.61 Accuracy: 0.83
# [train] Epoch 32/100 Iteration 33/81 Loss: 0.59 Accuracy: 0.84
# [train] Epoch 32/100 Iteration 49/81 Loss: 0.58 Accuracy: 0.84
# [train] Epoch 32/100 Iteration 65/81 Loss: 0.59 Accuracy: 0.84
# [train] Epoch 32/100 Iteration 81/81 Loss: 0.58 Accuracy: 0.84
# [train] Epoch 32/100 Iteration 81/81 Loss: 0.58 Accuracy: 0.84
# [val] Epoch 32/100 Iteration 1/41 Loss: 0.46 Accuracy: 0.88
# [val] Epoch 32/100 Iteration 9/41 Loss: 0.57 Accuracy: 0.84
# [val] Epoch 32/100 Iteration 17/41 Loss: 0.62 Accuracy: 0.83
# [val] Epoch 32/100 Iteration 25/41 Loss: 0.63 Accuracy: 0.83
# [val] Epoch 32/100 Iteration 33/41 Loss: 0.62 Accuracy: 0.84
# [val] Epoch 32/100 Iteration 41/41 Loss: 0.61 Accuracy: 0.84
# [val] Epoch 32/100 Iteration 41/41 Loss: 0.61 Accuracy: 0.84
# Epochs with no improvement 3
# [train] Epoch 33/100 Iteration 1/81 Loss: 0.59 Accuracy: 0.80
# [train] Epoch 33/100 Iteration 17/81 Loss: 0.55 Accuracy: 0.85
# [train] Epoch 33/100 Iteration 33/81 Loss: 0.56 Accuracy: 0.85
# [train] Epoch 33/100 Iteration 49/81 Loss: 0.57 Accuracy: 0.85
# [train] Epoch 33/100 Iteration 65/81 Loss: 0.57 Accuracy: 0.84
# [train] Epoch 33/100 Iteration 81/81 Loss: 0.57 Accuracy: 0.84
# [train] Epoch 33/100 Iteration 81/81 Loss: 0.57 Accuracy: 0.84
# [val] Epoch 33/100 Iteration 1/41 Loss: 0.60 Accuracy: 0.85
# [val] Epoch 33/100 Iteration 9/41 Loss: 0.63 Accuracy: 0.84
# [val] Epoch 33/100 Iteration 17/41 Loss: 0.61 Accuracy: 0.84
# [val] Epoch 33/100 Iteration 25/41 Loss: 0.60 Accuracy: 0.84
# [val] Epoch 33/100 Iteration 33/41 Loss: 0.60 Accuracy: 0.84
# [val] Epoch 33/100 Iteration 41/41 Loss: 0.60 Accuracy: 0.84
# [val] Epoch 33/100 Iteration 41/41 Loss: 0.60 Accuracy: 0.84
# Epoch 00033: reducing learning rate of group 0 to 1.0000e-07.
# Epochs with no improvement 4
# [train] Epoch 34/100 Iteration 1/81 Loss: 0.57 Accuracy: 0.84
# [train] Epoch 34/100 Iteration 17/81 Loss: 0.60 Accuracy: 0.84
# [train] Epoch 34/100 Iteration 33/81 Loss: 0.59 Accuracy: 0.84
# [train] Epoch 34/100 Iteration 49/81 Loss: 0.60 Accuracy: 0.84
# [train] Epoch 34/100 Iteration 65/81 Loss: 0.60 Accuracy: 0.84
# [train] Epoch 34/100 Iteration 81/81 Loss: 0.60 Accuracy: 0.84
# [train] Epoch 34/100 Iteration 81/81 Loss: 0.60 Accuracy: 0.84
# [val] Epoch 34/100 Iteration 1/41 Loss: 0.55 Accuracy: 0.88
# [val] Epoch 34/100 Iteration 9/41 Loss: 0.59 Accuracy: 0.84
# [val] Epoch 34/100 Iteration 17/41 Loss: 0.62 Accuracy: 0.84
# [val] Epoch 34/100 Iteration 25/41 Loss: 0.59 Accuracy: 0.85
# [val] Epoch 34/100 Iteration 33/41 Loss: 0.58 Accuracy: 0.85
# [val] Epoch 34/100 Iteration 41/41 Loss: 0.60 Accuracy: 0.84
# [val] Epoch 34/100 Iteration 41/41 Loss: 0.60 Accuracy: 0.84
# [train] Epoch 35/100 Iteration 1/81 Loss: 0.60 Accuracy: 0.82
# [train] Epoch 35/100 Iteration 17/81 Loss: 0.59 Accuracy: 0.84
# [train] Epoch 35/100 Iteration 33/81 Loss: 0.59 Accuracy: 0.84
# [train] Epoch 35/100 Iteration 49/81 Loss: 0.60 Accuracy: 0.84
# [train] Epoch 35/100 Iteration 65/81 Loss: 0.60 Accuracy: 0.84
# [train] Epoch 35/100 Iteration 81/81 Loss: 0.59 Accuracy: 0.84
# [train] Epoch 35/100 Iteration 81/81 Loss: 0.59 Accuracy: 0.84
# [val] Epoch 35/100 Iteration 1/41 Loss: 0.64 Accuracy: 0.82
# [val] Epoch 35/100 Iteration 9/41 Loss: 0.60 Accuracy: 0.84
# [val] Epoch 35/100 Iteration 17/41 Loss: 0.59 Accuracy: 0.84
# [val] Epoch 35/100 Iteration 25/41 Loss: 0.60 Accuracy: 0.84
# [val] Epoch 35/100 Iteration 33/41 Loss: 0.59 Accuracy: 0.84
# [val] Epoch 35/100 Iteration 41/41 Loss: 0.60 Accuracy: 0.84
# [val] Epoch 35/100 Iteration 41/41 Loss: 0.60 Accuracy: 0.84
# Epochs with no improvement 1
# [train] Epoch 36/100 Iteration 1/81 Loss: 0.58 Accuracy: 0.84
# [train] Epoch 36/100 Iteration 17/81 Loss: 0.57 Accuracy: 0.85
# [train] Epoch 36/100 Iteration 33/81 Loss: 0.58 Accuracy: 0.84
# [train] Epoch 36/100 Iteration 49/81 Loss: 0.59 Accuracy: 0.84
# [train] Epoch 36/100 Iteration 65/81 Loss: 0.59 Accuracy: 0.84
# [train] Epoch 36/100 Iteration 81/81 Loss: 0.58 Accuracy: 0.84
# [train] Epoch 36/100 Iteration 81/81 Loss: 0.58 Accuracy: 0.84
# [val] Epoch 36/100 Iteration 1/41 Loss: 0.65 Accuracy: 0.82
# [val] Epoch 36/100 Iteration 9/41 Loss: 0.60 Accuracy: 0.83
# [val] Epoch 36/100 Iteration 17/41 Loss: 0.63 Accuracy: 0.83
# [val] Epoch 36/100 Iteration 25/41 Loss: 0.61 Accuracy: 0.84
# [val] Epoch 36/100 Iteration 33/41 Loss: 0.60 Accuracy: 0.84
# [val] Epoch 36/100 Iteration 41/41 Loss: 0.59 Accuracy: 0.84
# [val] Epoch 36/100 Iteration 41/41 Loss: 0.59 Accuracy: 0.84
# [train] Epoch 37/100 Iteration 1/81 Loss: 0.48 Accuracy: 0.90
# [train] Epoch 37/100 Iteration 17/81 Loss: 0.58 Accuracy: 0.84
# [train] Epoch 37/100 Iteration 33/81 Loss: 0.57 Accuracy: 0.85
# [train] Epoch 37/100 Iteration 49/81 Loss: 0.58 Accuracy: 0.84
# [train] Epoch 37/100 Iteration 65/81 Loss: 0.59 Accuracy: 0.83
# [train] Epoch 37/100 Iteration 81/81 Loss: 0.59 Accuracy: 0.84
# [train] Epoch 37/100 Iteration 81/81 Loss: 0.59 Accuracy: 0.84
# [val] Epoch 37/100 Iteration 1/41 Loss: 0.51 Accuracy: 0.84
# [val] Epoch 37/100 Iteration 9/41 Loss: 0.58 Accuracy: 0.83
# [val] Epoch 37/100 Iteration 17/41 Loss: 0.58 Accuracy: 0.84
# [val] Epoch 37/100 Iteration 25/41 Loss: 0.60 Accuracy: 0.84
# [val] Epoch 37/100 Iteration 33/41 Loss: 0.60 Accuracy: 0.84
# [val] Epoch 37/100 Iteration 41/41 Loss: 0.60 Accuracy: 0.84
# [val] Epoch 37/100 Iteration 41/41 Loss: 0.60 Accuracy: 0.84
# Epochs with no improvement 1
# [train] Epoch 38/100 Iteration 1/81 Loss: 0.59 Accuracy: 0.79
# [train] Epoch 38/100 Iteration 17/81 Loss: 0.58 Accuracy: 0.84
# [train] Epoch 38/100 Iteration 33/81 Loss: 0.57 Accuracy: 0.84
# [train] Epoch 38/100 Iteration 49/81 Loss: 0.57 Accuracy: 0.85
# [train] Epoch 38/100 Iteration 65/81 Loss: 0.57 Accuracy: 0.85
# [train] Epoch 38/100 Iteration 81/81 Loss: 0.58 Accuracy: 0.84
# [train] Epoch 38/100 Iteration 81/81 Loss: 0.58 Accuracy: 0.84
# [val] Epoch 38/100 Iteration 1/41 Loss: 0.74 Accuracy: 0.84
# [val] Epoch 38/100 Iteration 9/41 Loss: 0.58 Accuracy: 0.85
# [val] Epoch 38/100 Iteration 17/41 Loss: 0.58 Accuracy: 0.85
# [val] Epoch 38/100 Iteration 25/41 Loss: 0.59 Accuracy: 0.84
# [val] Epoch 38/100 Iteration 33/41 Loss: 0.60 Accuracy: 0.84
# [val] Epoch 38/100 Iteration 41/41 Loss: 0.61 Accuracy: 0.84
# [val] Epoch 38/100 Iteration 41/41 Loss: 0.61 Accuracy: 0.84
# Epochs with no improvement 2
# [train] Epoch 39/100 Iteration 1/81 Loss: 0.51 Accuracy: 0.86
# [train] Epoch 39/100 Iteration 17/81 Loss: 0.59 Accuracy: 0.84
# [train] Epoch 39/100 Iteration 33/81 Loss: 0.59 Accuracy: 0.84
# [train] Epoch 39/100 Iteration 49/81 Loss: 0.58 Accuracy: 0.84
# [train] Epoch 39/100 Iteration 65/81 Loss: 0.59 Accuracy: 0.84
# [train] Epoch 39/100 Iteration 81/81 Loss: 0.58 Accuracy: 0.85
# [train] Epoch 39/100 Iteration 81/81 Loss: 0.58 Accuracy: 0.85
# [val] Epoch 39/100 Iteration 1/41 Loss: 0.39 Accuracy: 0.88
# [val] Epoch 39/100 Iteration 9/41 Loss: 0.61 Accuracy: 0.84
# [val] Epoch 39/100 Iteration 17/41 Loss: 0.60 Accuracy: 0.84
# [val] Epoch 39/100 Iteration 25/41 Loss: 0.59 Accuracy: 0.84
# [val] Epoch 39/100 Iteration 33/41 Loss: 0.60 Accuracy: 0.84
# [val] Epoch 39/100 Iteration 41/41 Loss: 0.61 Accuracy: 0.84
# [val] Epoch 39/100 Iteration 41/41 Loss: 0.61 Accuracy: 0.84
# Epochs with no improvement 3
# [train] Epoch 40/100 Iteration 1/81 Loss: 0.68 Accuracy: 0.82
# [train] Epoch 40/100 Iteration 17/81 Loss: 0.59 Accuracy: 0.85
# [train] Epoch 40/100 Iteration 33/81 Loss: 0.59 Accuracy: 0.84
# [train] Epoch 40/100 Iteration 49/81 Loss: 0.58 Accuracy: 0.85
# [train] Epoch 40/100 Iteration 65/81 Loss: 0.57 Accuracy: 0.85
# [train] Epoch 40/100 Iteration 81/81 Loss: 0.57 Accuracy: 0.85
# [train] Epoch 40/100 Iteration 81/81 Loss: 0.57 Accuracy: 0.85
# [val] Epoch 40/100 Iteration 1/41 Loss: 0.63 Accuracy: 0.80
# [val] Epoch 40/100 Iteration 9/41 Loss: 0.62 Accuracy: 0.84
# [val] Epoch 40/100 Iteration 17/41 Loss: 0.59 Accuracy: 0.85
# [val] Epoch 40/100 Iteration 25/41 Loss: 0.60 Accuracy: 0.85
# [val] Epoch 40/100 Iteration 33/41 Loss: 0.62 Accuracy: 0.84
# [val] Epoch 40/100 Iteration 41/41 Loss: 0.61 Accuracy: 0.84
# [val] Epoch 40/100 Iteration 41/41 Loss: 0.61 Accuracy: 0.84
# Epoch 00040: reducing learning rate of group 0 to 1.0000e-08.
# Epochs with no improvement 4
# [train] Epoch 41/100 Iteration 1/81 Loss: 0.59 Accuracy: 0.88
# [train] Epoch 41/100 Iteration 17/81 Loss: 0.57 Accuracy: 0.85
# [train] Epoch 41/100 Iteration 33/81 Loss: 0.57 Accuracy: 0.85
# [train] Epoch 41/100 Iteration 49/81 Loss: 0.57 Accuracy: 0.85
# [train] Epoch 41/100 Iteration 65/81 Loss: 0.58 Accuracy: 0.84
# [train] Epoch 41/100 Iteration 81/81 Loss: 0.58 Accuracy: 0.85
# [train] Epoch 41/100 Iteration 81/81 Loss: 0.58 Accuracy: 0.85
# [val] Epoch 41/100 Iteration 1/41 Loss: 0.59 Accuracy: 0.85
# [val] Epoch 41/100 Iteration 9/41 Loss: 0.56 Accuracy: 0.85
# [val] Epoch 41/100 Iteration 17/41 Loss: 0.58 Accuracy: 0.85
# [val] Epoch 41/100 Iteration 25/41 Loss: 0.59 Accuracy: 0.84
# [val] Epoch 41/100 Iteration 33/41 Loss: 0.59 Accuracy: 0.84
# [val] Epoch 41/100 Iteration 41/41 Loss: 0.60 Accuracy: 0.84
# [val] Epoch 41/100 Iteration 41/41 Loss: 0.60 Accuracy: 0.84
# Epochs with no improvement 5
# Early stopping!

# %%
plot_logs_classification(results_path, net_name, loss_acc)

# %%
preds_test, y_true = test_model(net_name, net_model, testing_set_loader)
# Out:
# Iteration 1/41
# Iteration 9/41
# Iteration 17/41
# Iteration 25/41
# Iteration 33/41
# Iteration 41/41

# %%
display_confusion_matrix(results_path, net_name, y_true, preds_test, class_names, annot=True, figsize=(19,17), fontsize=8)

# %%
print(classification_report(y_true, preds_test.argmax(1), target_names=class_names))
# Out:
#                                 precision    recall  f1-score   support
#
#                      Chihuahua       0.93      0.74      0.82        38
#               Japanese_spaniel       0.95      0.87      0.91        45
#                    Maltese_dog       0.82      0.92      0.87        61
#                       Pekinese       0.92      0.75      0.83        44
#                       Shih-Tzu       0.79      0.76      0.78        55
#               Blenheim_spaniel       0.93      0.98      0.95        53
#                       papillon       0.88      0.98      0.93        45
#                    toy_terrier       0.79      0.76      0.77        49
#            Rhodesian_ridgeback       0.83      0.79      0.81        38
#                   Afghan_hound       1.00      0.94      0.97        64
#                         basset       0.85      0.87      0.86        46
#                         beagle       0.77      0.79      0.78        52
#                     bloodhound       0.93      0.93      0.93        42
#                       bluetick       0.95      0.74      0.83        47
#        black-and-tan_coonhound       0.93      0.83      0.88        47
#                   Walker_hound       0.57      0.75      0.65        32
#               English_foxhound       0.67      0.52      0.59        42
#                        redbone       0.79      0.97      0.87        34
#                         borzoi       0.89      0.89      0.89        35
#                Irish_wolfhound       0.82      0.78      0.80        60
#              Italian_greyhound       0.82      0.75      0.79        44
#                        whippet       0.70      0.84      0.76        56
#                   Ibizan_hound       0.90      0.83      0.86        42
#             Norwegian_elkhound       0.98      0.85      0.91        62
#                     otterhound       1.00      0.87      0.93        38
#                         Saluki       0.91      0.93      0.92        45
#             Scottish_deerhound       0.85      0.91      0.88        56
#                     Weimaraner       0.88      0.90      0.89        39
#      Staffordshire_bullterrier       0.65      0.67      0.66        33
# American_Staffordshire_terrier       0.73      0.68      0.71        44
#             Bedlington_terrier       0.95      1.00      0.98        42
#                 Border_terrier       1.00      0.85      0.92        46
#             Kerry_blue_terrier       0.93      0.93      0.93        40
#                  Irish_terrier       0.84      0.88      0.86        49
#                Norfolk_terrier       0.76      0.71      0.73        41
#                Norwich_terrier       0.77      0.72      0.75        47
#              Yorkshire_terrier       0.71      0.78      0.74        41
#        wire-haired_fox_terrier       0.86      0.71      0.78        42
#               Lakeland_terrier       0.67      0.84      0.74        50
#               Sealyham_terrier       0.96      0.92      0.94        49
#                       Airedale       0.93      0.81      0.86        47
#                          cairn       0.81      0.83      0.82        46
#             Australian_terrier       0.77      0.67      0.72        51
#                 Dandie_Dinmont       0.89      0.89      0.89        47
#                    Boston_bull       0.80      0.88      0.84        42
#            miniature_schnauzer       0.83      0.83      0.83        36
#                giant_schnauzer       0.76      0.76      0.76        45
#             standard_schnauzer       0.69      0.69      0.69        26
#                 Scotch_terrier       0.88      0.76      0.81        37
#                Tibetan_terrier       0.84      0.82      0.83        51
#                  silky_terrier       0.72      0.88      0.79        52
#    soft-coated_wheaten_terrier       0.81      0.85      0.83        34
#    West_Highland_white_terrier       0.84      0.83      0.83        52
#                          Lhasa       0.65      0.72      0.69        47
#          flat-coated_retriever       0.78      0.85      0.82        34
#         curly-coated_retriever       0.83      0.81      0.82        43
#               golden_retriever       0.70      0.90      0.79        21
#             Labrador_retriever       0.68      0.71      0.70        45
#       Chesapeake_Bay_retriever       0.94      0.88      0.91        50
#    German_short-haired_pointer       0.80      0.86      0.83        37
#                         vizsla       0.89      0.85      0.87        46
#                 English_setter       0.93      0.78      0.85        50
#                   Irish_setter       0.89      0.89      0.89        35
#                  Gordon_setter       1.00      0.89      0.94        36
#               Brittany_spaniel       0.76      0.82      0.78        38
#                        clumber       0.97      1.00      0.99        36
#               English_springer       0.76      0.97      0.85        38
#         Welsh_springer_spaniel       0.89      0.85      0.87        39
#                 cocker_spaniel       0.92      0.84      0.88        43
#                 Sussex_spaniel       0.97      0.85      0.91        34
#            Irish_water_spaniel       0.82      0.97      0.89        34
#                         kuvasz       0.91      0.82      0.86        38
#                     schipperke       0.79      0.84      0.81        31
#                    groenendael       0.86      0.95      0.90        39
#                       malinois       0.83      0.91      0.87        33
#                         briard       0.73      0.86      0.79        28
#                         kelpie       0.71      0.74      0.72        39
#                       komondor       0.92      0.88      0.90        40
#           Old_English_sheepdog       0.93      0.87      0.90        45
#              Shetland_sheepdog       0.82      0.90      0.86        40
#                         collie       0.61      0.51      0.56        39
#                  Border_collie       0.74      0.74      0.74        39
#           Bouvier_des_Flandres       0.74      0.76      0.75        33
#                     Rottweiler       0.90      0.92      0.91        51
#                German_shepherd       0.77      0.77      0.77        31
#                       Doberman       0.85      0.85      0.85        39
#             miniature_pinscher       0.69      0.92      0.79        37
#     Greater_Swiss_Mountain_dog       0.73      0.82      0.77        39
#           Bernese_mountain_dog       0.86      0.92      0.89        52
#                    Appenzeller       0.64      0.60      0.62        42
#                    EntleBucher       0.83      0.73      0.78        52
#                          boxer       0.73      0.80      0.76        30
#                   bull_mastiff       0.80      0.92      0.85        38
#                Tibetan_mastiff       0.97      0.85      0.91        34
#                 French_bulldog       0.85      0.81      0.83        43
#                     Great_Dane       0.89      0.93      0.91        44
#                  Saint_Bernard       1.00      0.95      0.98        44
#                     Eskimo_dog       0.50      0.22      0.31        41
#                       malamute       0.79      0.82      0.81        51
#                 Siberian_husky       0.47      0.71      0.57        38
#                  affenpinscher       0.81      0.76      0.78        38
#                        basenji       0.97      0.89      0.93        65
#                            pug       0.98      0.88      0.93        51
#                       Leonberg       0.96      0.95      0.95        55
#                   Newfoundland       0.84      0.91      0.87        57
#                 Great_Pyrenees       0.92      0.78      0.85        46
#                        Samoyed       0.86      0.98      0.91        43
#                     Pomeranian       0.78      0.93      0.85        43
#                           chow       0.98      0.91      0.94        55
#                       keeshond       1.00      1.00      1.00        52
#              Brabancon_griffon       0.89      0.94      0.92        36
#                       Pembroke       0.79      0.81      0.80        47
#                       Cardigan       0.76      0.72      0.74        39
#                     toy_poodle       0.80      0.53      0.64        45
#               miniature_poodle       0.39      0.62      0.48        32
#                standard_poodle       0.80      0.75      0.78        44
#               Mexican_hairless       0.97      0.94      0.96        35
#                          dingo       0.82      0.82      0.82        40
#                          dhole       0.97      0.94      0.95        33
#            African_hunting_dog       0.94      1.00      0.97        32
#
#                       accuracy                           0.83      5145
#                      macro avg       0.83      0.83      0.83      5145
#                   weighted avg       0.84      0.83      0.83      5145
